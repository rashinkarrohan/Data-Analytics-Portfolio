# %% [markdown]
# ## Importing Libraries
# **Pandas** :  Pandas Library is used for the *Data Manipulation and Analysis*.
#
# **Numpy**  :  Numpy Library is use for Mathematical Computation and used as Arrays.
#
# **Matplotlib** : Matplotlib Library is used to create Visualization from the Data.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 	Importing Dataset:
#
# Above Data is Obtain by Scraping Makkan.com using selenium and BeautifulSoup.

# %%
df = pd.read_csv('Pune_Housing.csv')

# %% [markdown]
# As the Unnamed: 0 not useful for us we will drop it.

# %%
df.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %% [markdown]
# Returns the first 5 rows of the Dataset.

# %%
df.head()
# Out:
#    bhk   locality  sqft  price_per_sqft  bath  Price_Lakhs  Build_year  Age
# 0    2      Ravet  1000            4500   2.0         45.0      2022.0  1.0
# 1    1  Tathawade   670            5373   1.0         36.0      2026.0  5.0
# 2    2  Tathawade  1100            5363   2.0         59.0      2025.0  4.0
# 3    2      Ravet  1100            4909   2.0         54.0      2025.0  4.0
# 4    1    Bavdhan   664            5647   1.0         37.5      2024.0  3.0

# %% [markdown]
# ## Identification of data types:

# %% [markdown]
# Return the columns name with their Dtypes.

# %%
df.dtypes
# Out:
# bhk                 int64
# locality           object
# sqft                int64
# price_per_sqft      int64
# bath              float64
# Price_Lakhs       float64
# Build_year        float64
# Age               float64
# dtype: object

# %% [markdown]
# ## Size of the Dataset
#
# first it will return the rows and then columns size. (rows,columns)

# %%
df.shape
# Out:
# (26293, 8)

# %% [markdown]
# ## Statistical Summary

# %%
df.describe()
# Out:
#                 bhk          sqft  price_per_sqft          bath   Price_Lakhs  \
# count  26293.000000  26293.000000    26293.000000  21254.000000  26293.000000
# mean       2.306241   1263.274446     7830.440193      2.379693    105.009617
# std        0.818501    839.292115     3121.090794      0.938064    102.920637
# min        1.000000    195.000000      418.000000      1.000000      2.400000
# 25%        2.000000    783.000000     5833.000000      2.000000     50.970000
# 50%        2.000000   1024.000000     7241.000000      2.000000     72.000000
# 75%        3.000000   1410.000000     9230.000000      3.000000    115.000000
# max        8.000000   9500.000000   113333.000000      9.000000   1000.000000
#
#          Build_year           Age
# count  26293.000000  26293.000000
# mean    2016.519910     -4.480090
# std       28.202798     28.202798
# min        1.000000  -2020.000000
# 25%     2015.000000     -6.000000
# 50%     2019.000000     -2.000000
# 75%     2022.000000      1.000000
# max     2030.000000      9.000000

# %%
df.head()
# Out:
#    bhk   locality  sqft  price_per_sqft  bath  Price_Lakhs  Build_year  Age
# 0    2      Ravet  1000            4500   2.0         45.0      2022.0  1.0
# 1    1  Tathawade   670            5373   1.0         36.0      2026.0  5.0
# 2    2  Tathawade  1100            5363   2.0         59.0      2025.0  4.0
# 3    2      Ravet  1100            4909   2.0         54.0      2025.0  4.0
# 4    1    Bavdhan   664            5647   1.0         37.5      2024.0  3.0

# %% [markdown]
# ## Value_counts for Different Features

# %%
df.bath.value_counts()
# Out:
# 2.0    11286
# 3.0     5063
# 1.0     2566
# 4.0     1581
# 5.0      633
# 6.0      116
# 7.0        7
# 9.0        1
# 8.0        1
# Name: bath, dtype: int64

# %%
df.bhk.value_counts()
# Out:
# 2    13808
# 3     6983
# 1     3392
# 4     1891
# 5      203
# 6       12
# 8        2
# 7        2
# Name: bhk, dtype: int64

# %%
df.locality.value_counts()
# Out:
# Kharadi                 3692
# Kalyani Nagar           1852
# Viman Nagar             1770
# Wagholi                 1583
# Hinjewadi               1571
#                         ...
# Wakad Hinjewadi Road       1
# Shatrunjay Nagar           1
# Old Sanghvi                1
# Rahatani Link Road         1
# Mohan Nagar                1
# Name: locality, Length: 396, dtype: int64

# %%
# locality_flats = df.locality.value_counts()

# %%
# # Select the values where the count is less than 3 (or 5 if you like)
# remove = locality_flats[locality_flats < 50].index

# # Keep rows where the city column is not in to_remove
# df = df[~df.locality.isin(remove)]

# %% [markdown]
# During Data Cleaning We have not strip the Data, So their are white spaces we need to clean that

# %%
df.locality.unique()
# Out:
# array(['Ravet', 'Tathawade', 'Bavdhan', 'Aundh', 'Sangamvadi',
#        'Ambegaon 1', 'Kharadi', 'Mundhwa', 'Baner', 'Hinjewadi',
#        'Manjari', 'Dhanori', 'Wadgaon Sheri', 'Kondhwa', 'Vadgaon',
#        'Balewadi', 'Wanowrie', 'Mahalunge', 'Sus', 'Wakad',
#        'Vishrantwadi', 'Undri', 'Alandi', 'Lohegaon', 'Nigdi', 'Thergaon',
#        'Lake Town Road', 'Vadgaon Budruk', 'Pashan', 'Dighi', 'Fursungi',
#        'Chikhali', 'Dhayari', 'Sasane Nagar', 'Magarpatta',
#        'Keshav Nagar', 'Pimple Nilakh', 'Ravet Village Road',
#        'Kalyani Nagar', 'Wagholi', 'Viman Nagar', 'Hadapsar',
#        'Bavdhan Budruk', 'Moshi', 'NIBM Annex Mohammadwadi', 'Varale',
#        'Mamurdi', 'Katraj', 'Wadgaon Budruk', 'Koregaon Park',
#        'bhekarai nagar', 'Shivane', 'Amanora Town Centre', 'Karve Nagar',
#        'Pimple Gurav', 'Nere', 'Anand Park',
#        'Bijali Nagar PimpriChinchwad', 'Bhegade Aali', 'Handewadi',
#        'Loni Kalbhor', 'Rasta Peth', 'Pimple Saudagar', 'Kiwale', 'Narhe',
#        'Chakan', 'BT Kavre Road', 'Chinchwad Gaon', 'Patil Nager',
#        'Kothrud', 'Charholi Budruk', 'Fatima Nagar', 'Talegaon Dabhade',
#        'Sunarwadi', 'B T Kawde Road', 'Bopodi', 'Ambegaon Budruk',
#        'Ambegaon', 'NIBM Road', 'Wanwadi', 'Boat Club Road', 'Chinchwad',
#        'Yerawada', 'Mohammed wadi', 'Warje', 'Parvati Darshan', 'Khopoli',
#        'Pan Card Club Road', 'Baner Road', 'Mahalunge Baner Road',
#        'Sopan Baug', 'Bakhori', 'Punawale', 'Pimpri', 'Jambhul',
#        'Gahunje', 'Rahatani', 'Gujarat Colony Road', 'Lavasa',
#        'Hinjewadi Phase 1', 'Mumbai Pune Highway', 'Uruli Kanchan',
#        'Rakshlekha Society', 'Kondhwa Budrukh', 'Kondhwa Road',
#        'Handewadi Road Undri', 'Kondhwa Khurd', 'Pisoli Road',
#        'NIBM Kondhwa Link Road', 'Wakad Pune', 'Bibwewadi',
#        'Fursungi Road', 'Wadachiwadi Road', 'Tingre Nagar', 'Ashok Nagar',
#        'Shivaji Nagar', 'Akurdi', 'Valvan Lonavla', 'Bhoirwadi',
#        'Pashan Sus Road', 'Baner Pashan Link Road', 'Porwal Road',
#        'Maharashtra Housing Board',
#        'Maharashtra Industrial Development Corporation Area',
#        'Balewadi High Street', 'Lonkar Nagar', 'Talawade Gaon',
#        'Pimpri Chinchwad', 'Bhumkar Chowk Road', 'Kasarwadi',
#        'Hinjewadi Phase 2', 'Bhukum', 'Gokul Nagar', 'Bhugaon',
#        'Agalambe', 'Handewadi Road', 'Magarpatta Road',
#        'Law College Road', 'Chinchwad Station Road', 'Gujarwadi Road',
#        'Bopkhel', 'Deccan Gymkhana', 'Somatane', 'Kondhwa Bk',
#        'Uruli Devachi', 'Dattavadi', 'Balaji Nagar', 'Dhanakwadi',
#        'Purna Nagar Chikhali CDC', 'kesnand', 'Giridhar Nagar',
#        'EON Free Zone', 'Majestique City Society Road', 'Dange Chowk',
#        'Koregaon Bhima', 'Rajgurunagar', 'Narhe Road', 'Yojana Nagar',
#        'Padmavati', 'Anand Tirth Nagar', 'Manjri Bk', 'Walekar Wadi',
#        'Talegaon Dhamdhere', 'Chimbali', 'Manjari Budruk', 'New Sangavi',
#        'Warje Malwadi', 'Pandav Nagar', 'Benkar Vasti Road',
#        'Anand Nagar', 'Amanora Park Town', 'Satar Nagar', 'Ranjangaon',
#        'Alandi Road', 'Navi Peth', 'Kolhewadi', 'Pirangut', 'Khadki',
#        'Urmila Housing Society', 'bhusari colony', 'Balewadi Road',
#        'Bhawani Peth', 'Koregaon Park Annexe', 'Shatrunjay Nagar',
#        'Ram Tekdi', 'Kale Padal', 'Dhankawadi Police Station Road',
#        'Dehu', 'Nehru Nagar', 'BT Kawde', 'Pune Cantonment', 'Swargate',
#        'Fursungi Gaon', 'Parkhe Vasti', 'Wakadkar Wasti', 'Phase 2',
#        'Nangargaon', 'New Kalyani Nagar', 'wakad', 'Sus Road Pashan',
#        'Kaspate Vasti', 'Sai Prasad Society Road', 'Sutar Wadi',
#        'Sainik Vihar', 'charholi Khurd', 'Jay Malhar Colony',
#        'Maharashtra Vidhyut Department Quarters',
#        'Residential Flat Phursungi', 'Phursungi Village Road',
#        'Kirkatwadi', 'Mitha Nagar', 'Talegaon', 'Vidyanagar',
#        'Dahanukar Colony', 'Marvel Fria Road', 'Gavliwada',
#        'Park Infinia', 'Shastri Nagar', 'Udyog Nagar',
#        'Hadapsar Fursungi Road', 'Dhayari Phata', 'Vikas Nagar',
#        'MAE Campus', 'NIBM', 'Bhosle Nagar', 'Shivapur',
#        'Lal Bahadur Shastri Road', 'Senapati Bapat Road', 'Bhumkar Nagar',
#        'Bhosari', 'Bazarpeth', 'BRT main bus stop Vishrantwadi Pune',
#        'Mahalunge Ingale', 'Ivy Estate Road', 'Raisoni College Road',
#        'Baif Road', 'Bakori Road', 'Ubale Nagar', 'Khandve Nagar',
#        'Kesnand Wade Gaon Road', 'Pradhikaran Nigdi', 'NIBM Annexe',
#        'katraj kondhwa road', 'Ambegaon Khurd', 'bibvewadi',
#        'Bund Garden Road', 'Sangvi', 'Meeta Nagar', 'sinhagad road',
#        'khese park', 'Vallabh Nagar', 'Bund Garden', 'Gultekdi',
#        'Vasani Nagar', 'Mukund Nagar', 'Kalewadi', 'Nigdi Sector 24',
#        'Vijay Nagar', 'Lonikand', 'Lohegaon Road', 'Sadashiv Peth',
#        'Vadgaon Sheri', 'gondhale nagar', 'Samarth Nagar', 'Yewalewadi',
#        'Narayangaon', 'Kothrud Depot Road', 'Kondhwa Budruk',
#        'Dange Chowk Road', 'Bhumkar Bridge', 'Dhankawadi Road', 'Pisoli',
#        'Gulab Nagar Pune', 'Dhankawadi', 'Chandkhed', 'hingne Khurd',
#        'Karpe Nagar', 'Sinhagad Fort', 'Bhumkar Nagar Ambegaon BK',
#        'Dhanori Road', 'Salisbury Park',
#        'Trishul Sahakari Housing Society', 'TC Colony',
#        'Range Hill Estate', 'Dapodi', 'Guruwar Peth',
#        'Rahatani Link Road', 'Dhayari Village', 'Katraj Ambegaon BK Road',
#        'Kalewadi Pandhapur Road', 'Shankar Kalat Nagar', 'Paud Road',
#        'Erandwane', 'Mumbai Pune Bypass Road', 'Kaspate Vasti Road',
#        'Bhunde Vasti', 'Tukai Darshan', 'Baramati',
#        'Residential Flat Baramati', 'Bhagwan Tatyasaheb Kawade Road',
#        'Pune Solapur Road', 'Pune Station', 'Uttam Nagar',
#        'Salunke Vihar', 'Shukrawar Peth', 'Kharadi Bypass Road',
#        'Vitthal Nagar', 'Somwar Peth', 'Mohan Nagar', 'Vanaz corner',
#        'Sathe Nagar', 'shindewadi', 'Rambaug Colony', 'Manjari Khurd',
#        'Sai chowk', 'Phase 3 Hinjewadi Rajiv Gandhi Infotech Park',
#        'Ambegaon Pathar', 'Shewalewadi', 'Chandrabhaga Nagar',
#        'Undri Hadapsar Road', 'Pune Satara Road', 'Bibwewadi Annex',
#        'Bharati Vidyapeeth Campus', 'Khadki Bazar', 'Ambe Gaon',
#        'Pandhari Nagar', 'Mundhwa Road', 'Bijli Nagar', 'Wageshwar Nagar',
#        'Budhwar Peth', 'Sahakar Nagar', 'Sukhsagar Nagar',
#        'Narhe Dhayari Road', 'Sinhgad Road', 'Ramkrishna Paramhans Nagar',
#        'Model Colony', 'Vishnu Dev Nagar', 'Satav Nagar', 'Manohar Nagar',
#        'Boat Club Rd', 'Viman Nagar Central', 'Jadhavwadi', 'Lavale',
#        'Old Sanghvi', 'Khadakwasla', 'Kamshet', 'Market yard',
#        'Bhosale Garden Road', 'Narayan Peth', 'PimpriChinchwad Link Road',
#        'Dhiree Village', 'Bhagwan Nagar', 'Nana Peth', 'Eon IT Park Road',
#        'Ram wadi', 'Jambhulwadi Road', 'Magar Stadium Road', 'TMV Colony',
#        'Shantiban Society', 'SKF Colony', 'Dattanagar', 'Wanawadi Gaon',
#        'Donje', 'Mitra Mandal Chowk', 'Koregaon Mul', 'Lulla Nagar',
#        'Hills & Dales', 'Talwade', 'Vadgaon Maval', 'Nyati Estate Road',
#        'Dattawadi', 'Charholi Kurd', 'Ghule Nagar', 'Shikrapur',
#        'Papde Wasti', 'Nimbaj Nagar', 'Wakad Hinjewadi Road', 'Malwadi',
#        'Ghorpadi', 'Yashwantrao Chavan Nagar', 'Old Sangvi',
#        'Katraj Kondhwa Rd', 'Kolte Patil', 'Vidnyan Nagar Society',
#        'Bavdhan Road', 'Balewadi Phata', 'Vidnyan Nagar Road',
#        'Dhole Patil Road', 'Kesnand Road', 'Yashwant Nagar',
#        'Salunke Vihar Road', 'Daund', 'Ghule Vasti', 'Belekar Wasti',
#        'Vaiduwadi', 'Sambhajinagar'], dtype=object)

# %%
df.locality = df.locality.str.strip()

# %%
list1 = list(df.locality.unique())

# %%
df[df['locality'] == 'Kharadi'].price_per_sqft.median()
# Out:
# 7303.0

# %%
list2 = []
for i in list1:
    list2.append((i ,df[df['locality'] == i].price_per_sqft.mean()))

# %%
df_Region_price = pd.DataFrame(list2)

# %%
df_Region_price.sort_values(by=1,ascending=False).head()
# Out:
#                    0             1
# 366    Hills & Dales  62500.000000
# 306    Vitthal Nagar  21700.000000
# 115    Shivaji Nagar  18200.947368
# 254     Mukund Nagar  17913.500000
# 141  Deccan Gymkhana  16314.000000

# %%
fig = plt.figure() # create figure

plot1 = fig.add_subplot(1,2,1) # add subplot 1 (1 row, 2 columns, first plot)
plot2 = fig.add_subplot(1,2,2) # add subplot 2 (1 row, 2 columns, second plot). See tip below**
sns.boxplot(x='Price_Lakhs',data=df,ax=plot1,width=0.5,color='green',fliersize=2,linewidth=1)
sns.boxplot(x='sqft',data=df,ax=plot2,width=0.5,color='green',fliersize=2,linewidth=1)



fig = plt.figure() # create figure

plot1 = fig.add_subplot(1,2,1) # add subplot 1 (1 row, 2 columns, first plot)
plot2 = fig.add_subplot(1,2,2) # add subplot 2 (1 row, 2 columns, second plot). See tip below**
sns.boxplot(x='Age',data=df,ax=plot1,width=0.5,color='green',fliersize=2,linewidth=1)
sns.boxplot(x='price_per_sqft',data=df,ax=plot2,width=0.5,color='green',fliersize=2,linewidth=1)
# Out:
# <AxesSubplot:xlabel='price_per_sqft'>

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#                      bhk      sqft  price_per_sqft      bath  Price_Lakhs  \
# bhk             1.000000  0.773811        0.313930  0.889202     0.700197
# sqft            0.773811  1.000000        0.224836  0.811670     0.862196
# price_per_sqft  0.313930  0.224836        1.000000  0.361443     0.591958
# bath            0.889202  0.811670        0.361443  1.000000     0.717006
# Price_Lakhs     0.700197  0.862196        0.591958  0.717006     1.000000
# Build_year     -0.020377 -0.041963       -0.021757 -0.028177    -0.043783
# Age            -0.020377 -0.041963       -0.021757 -0.028177    -0.043783
#
#                 Build_year       Age
# bhk              -0.020377 -0.020377
# sqft             -0.041963 -0.041963
# price_per_sqft   -0.021757 -0.021757
# bath             -0.028177 -0.028177
# Price_Lakhs      -0.043783 -0.043783
# Build_year        1.000000  1.000000
# Age               1.000000  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure() # create figure

plot1 = fig.add_subplot(1,3,1) # add subplot 1 (1 row, 2 columns, first plot)
plot2 = fig.add_subplot(1,3,2) # add subplot 2 (1 row, 2 columns, second plot). See tip below**
plot3 = fig.add_subplot(1,3,3) # add subplot 1 (1 row, 2 columns, first plot)

df.plot(kind='scatter', x='bhk', y='Price_Lakhs', figsize=(10, 6), color='darkblue',ax=plot1) # add to subplot 1
df.plot(kind='scatter', x='bath', y='Price_Lakhs', figsize=(10, 6), color='darkblue',ax=plot2) # add to subplot 1
df.plot(kind='scatter', x='sqft', y='Price_Lakhs', figsize=(10, 6), color='darkblue',ax=plot3) # add to subplot 1
# Out:
# <AxesSubplot:xlabel='sqft', ylabel='Price_Lakhs'>

# %%
sns.pairplot(df,height=1.8)

# %%
df.to_csv('../4. Model Building/Pune_Housing.csv')
